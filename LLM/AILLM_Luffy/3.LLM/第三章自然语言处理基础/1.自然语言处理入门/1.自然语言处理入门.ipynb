# %% [markdown]
# # 1 自然语言处理入门
#
# ### 学习目标
#
# * 了解什么是自然语言处理.
# * 了解自然语言处理的发展简史.
# * 了解自然语言处理的应用场景.
# * 了解本教程中的自然语言处理.

# %% [markdown]
# # 1 什么是自然语言处理
#
# * 自然语言处理（Natural Language Processing, 简称NLP）是计算机科学与语言学中关注于计算机与人类语言间转换的领域。

# %% [markdown]
# # 2 自然语言处理的发展简史

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3 自然语言处理的应用场景
#
# * 语音助手
# * 机器翻译
# * 搜索引擎
# * 智能问答
# * ...
#
# ## 3.1 语音助手
#
# * 科大讯飞语音识别技术访谈!

# %% [markdown]
# ## 3.2 机器翻译
#
# * CCTV上的机器翻译系统, 让世界聊得来!
